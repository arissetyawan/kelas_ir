# %% [markdown]
# ### contoh
# Di bawah adalah program contoh

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = np.arange(0.0 , 2.0, 0.01)
y = np.sin(2 * np.pi * x)
plt.plot(x,y)
plt.show()
